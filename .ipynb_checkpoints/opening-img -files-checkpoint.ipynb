# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
import cv2

# %%
img=cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
final =cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(final)

# %%
img_gray=cv2.imread("DATA/00-puppy.jpg",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray,cmap='magma')

# %%
final.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(cv2.resize(final,(1000,400)))

# %%
w_ratio=0.5
h_ratio=0.2

# %%
new_img=cv2.resize(final,(0,0),final,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (260, 975, 3)

# %%
new_img=cv2.flip(final,-1)

# %%
plt.imshow(new_img)

# %%
# fig=plt.figure(figsize=(2,5))
# ax=fig.add_subplot(111)
# ax.imshow(final)
